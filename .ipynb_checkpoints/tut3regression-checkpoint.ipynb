# %%
import pandas as pd
import seaborn as sns
import sklearn
from sklear import linear_model

# %%
df=pd.read_csv("mtrain.csv")
#m then  import 
#m then read the 
#m lmplot 
#m then linearregression
#then predic  
# then 
#m
#m
#m

# %%
df
# Out:
#    age   premium
# 0    25    18000
# 1    30    32000
# 2    35    40000
# 3    40    47000
# 4    45    56000

# %%
df.columns = df.columns.str.strip()
#m single variable regression

# %%
sns.lmplot(x="age",y="premium",data=df)
# for the better visualixe scatter plo use

# %%
reg=linear_modelLinearRegression();#m read dataset 
                                    #then linearregression the obj createe
                            #then fit
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 reg=LinearRegression();#m read dataset
#       2                                     #then linearregression the obj createe
#       3                             #then fit
#
# NameError: name 'LinearRegression' is not defined

# %%
reg.fit(df[["age"]],df["premium"])
#reshape then mulidimesional use
# Out:
# LinearRegression()

# %%
reg.predict([[33]])#the age input give
# Out:
# C:\Users\COMP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([34960.])

# %%
reg.coef_
#the remove coefficient slope
# Out:
# array([1820.])

# %%
reg.intercept_
#remove intercept c
# Out:
# -25100.0
