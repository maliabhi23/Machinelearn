# %%
import pandas as pd
# Out:
# C:\Users\COMP\AppData\Local\Temp\ipykernel_12676\2035458946.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
dataset=pd.read_csv("IrisLogismultmmm.csv")

# %%
dataset
# Out:
#    msepalLengthCm  SepeWidthCm  PetalLengthCm  petalwidthCmmm          species
# 0             6.8          3.2            5.9             2.3    Iris-virginic
# 1             6.9          3.1            5.1             2.3    Iris-virginic
# 2             4.9          3.0            1.4             0.2    Iris-seastoas
# 3             5.6          3.0            4.5             1.5  Iris-veriscolor
# 4             4.8          3.1            1.6             0.2    Iris-seastoas
# 5             5.8          2.8            5.1             2.4    Iris-virginic
# 6             7.2          3.6            6.1             2.5    Iris-virginic
# 7             5.1          3.5            1.4             0.3    Iris-seastoas
# 8             4.7          3.2            1.6             0.2    Iris-seastoas
# 9             6.6          3.0            4.4             1.4  Iris-veriscolor

# %%
dataset["species"].unique
# Out:
# <bound method Series.unique of 0      Iris-virginic
# 1      Iris-virginic
# 2      Iris-seastoas
# 3    Iris-veriscolor
# 4      Iris-seastoas
# 5      Iris-virginic
# 6      Iris-virginic
# 7      Iris-seastoas
# 8      Iris-seastoas
# 9    Iris-veriscolor
# Name: species, dtype: object>

# %%
dataset["species"].replace({'Iris-virginic':'1','Iris-veriscolor':'2','Iris-seastoas':'3'},inplace=True)

# %%
dataset
# Out:
#    msepalLengthCm  SepeWidthCm  PetalLengthCm  petalwidthCmmm species
# 0             6.8          3.2            5.9             2.3       1
# 1             6.9          3.1            5.1             2.3       1
# 2             4.9          3.0            1.4             0.2       3
# 3             5.6          3.0            4.5             1.5       2
# 4             4.8          3.1            1.6             0.2       3
# 5             5.8          2.8            5.1             2.4       1
# 6             7.2          3.6            6.1             2.5       1
# 7             5.1          3.5            1.4             0.3       3
# 8             4.7          3.2            1.6             0.2       3
# 9             6.6          3.0            4.4             1.4       2

# %%
from sklearn.model_selection import train_test_split

# %%
dataset.columns
# Out:
# Index(['msepalLengthCm', 'SepeWidthCm', 'PetalLengthCm', 'petalwidthCmmm',
#        'species'],
#       dtype='object')

# %%
 X_train, X_test, y_train, y_test =train_test_split(dataset[['msepalLengthCm','SepeWidthCm','PetalLengthCm','petalwidthCmmm']],dataset['species'],test_size=0.2)

# %%
len(X_train)
# Out:
# 8

# %%
len(X_test)
# Out:
# 2

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
lr.fit(X_test,y_test)
# Out:
# LogisticRegression()

# %%
lr.predict(X_test)
# Out:
# array(['1', '3'], dtype=object)

# %%
X_test #m m m({'Iris-virginic':'1','Iris-veriscolor':'2','Iris-seastoas':'3'
# Out:
#    msepalLengthCm  SepeWidthCm  PetalLengthCm  petalwidthCmmm
# 0             6.8          3.2            5.9             2.3
# 7             5.1          3.5            1.4             0.3

# %%
lr.score(X_test,y_test)
# Out:
# 1.0

# %%
import seaborn as sns

# %%
sns.pairplot(dataset[['msepalLengthCm','SepeWidthCm','PetalLengthCm','petalwidthCmmm','species']],hue='species')
